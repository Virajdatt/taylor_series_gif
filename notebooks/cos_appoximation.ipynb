# %%
import sys; sys.path.insert(0, '..') # helps importing our modules
from src.approx import ts_cos_x, approx_plotting
import math

# %% [markdown]
# ## Value of cos(0)

# %%
ts_cos_x(0, 3)
# Out:
# 1.0

# %% [markdown]
# ## Value of cos(90) angle in degree

# %%
int(ts_cos_x(math.radians(90), 3))
# Out:
# 0

# %% [markdown]
# # Plot iteratively value of cos between -360 to 360 degrees with increasing approxmation in the Taylor series (polynomial degrees upto 9)

# %%
fnames = approx_plotting(10)

# %% [markdown]
# ## Above we can see by the 9th polynomial degree the Taylor series equation for cos function is able to approximate the function very accurately i.e depicated in the final graph
